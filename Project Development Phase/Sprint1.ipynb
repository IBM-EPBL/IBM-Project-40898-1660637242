# %%
import pandas as pd

# %% [markdown]
# Load the dataset

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd/content/drive/MyDrive/sign picture
# Out:
# /content/drive/MyDrive/sign picture

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# 'conversation engine for deaf and dumb.zip'

# %%
pwd
# Out:
# '/content/drive/MyDrive/sign picture'

# %%
# !unzip 'conversation engine for deaf and dumb.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset/training_set/D/73.png
#   inflating: Dataset/training_set/D/730.png
#   inflating: Dataset/training_set/D/731.png
#   inflating: Dataset/training_set/D/732.png
#   inflating: Dataset/training_set/D/733.png
#   inflating: Dataset/training_set/D/734.png
#   inflating: Dataset/training_set/D/735.png
#   inflating: Dataset/training_set/D/736.png
#   inflating: Dataset/training_set/D/737.png
#   inflating: Dataset/training_set/D/738.png
#   inflating: Dataset/training_set/D/739.png
#   inflating: Dataset/training_set/D/74.png
#  extracting: Dataset/training_set/D/740.png
#   inflating: Dataset/training_set/D/741.png
#   inflating: Dataset/training_set/D/742.png
#   inflating: Dataset/training_set/D/743.png
#   inflating: Dataset/training_set/D/744.png
#   inflating: Dataset/training_set/D/745.png
#   inflating: Dataset/training_set/D/746.png
#   inflating: Dataset/training_set/D/747.png
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
Train_data=ImageDataGenerator(rescale=1./255,horizontal_flip= True,vertical_flip= True,zoom_range=0.2)

# %%
Test_data=ImageDataGenerator(rescale=1./255)

# %%
x_train=Train_data.flow_from_directory(r"/content/drive/MyDrive/sign picture/Dataset/training_set",target_size=(64,64),
                                       class_mode="categorical",batch_size=24)
# Out:
# Found 15030 images belonging to 9 classes.

# %%
x_test=Test_data.flow_from_directory(r"/content/drive/MyDrive/sign picture/Dataset/test_set",target_size=(64,64),
                                       class_mode="categorical",batch_size=24)
# Out:
# Found 2250 images belonging to 9 classes.
